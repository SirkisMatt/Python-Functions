# %% [markdown]
# <a href="https://colab.research.google.com/github/SirkisMatt/Python-Functions/blob/master/text_mine_with_data_set%2C_workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Start with loading all necessary libraries
import numpy as np
#Numpy provides fast mathematical function processing
import pandas as pd
#Pandas is used for easy indexing and data collection tools
from PIL import Image
#Pillow is a very good Python Image library
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#I am importing necessary packages for Data Visualizations in Python
import matplotlib.pyplot as plt
% matplotlib inline

# %%
#"The data set we will be using today is "The Top 1000 baby names from 1880 - 2000"
Wordclouddata = pd.read_csv("https://raw.githubusercontent.com/hadley/data-baby-names/master/baby-names.csv")
#The above function is how you import

# %%
#from google.colab import files
#upload = files.upload()
print("Use the above function to upload csv files from your computer")
#The above function to upload csv files from your computer
# Out:
#      <input type="file" id="files-0dc68032-806e-4156-b91d-3180b3219a4d" name="files[]" multiple disabled />
#      <output id="result-0dc68032-806e-4156-b91d-3180b3219a4d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Use the above function to upload csv files from your computer

# %%
#This tells me I have 258,000 rows of data and 4 colums
Wordclouddata.shape
# Out:
# (258000, 4)

# %%
#Once you add number it gives that numer of rows
Wordclouddata.head(9)
# Out:
#    year     name   percent  sex
# 0  1880     John  0.081541  boy
# 1  1880  William  0.080511  boy
# 2  1880    James  0.050057  boy
# 3  1880  Charles  0.045167  boy
# 4  1880   George  0.043292  boy
# 5  1880    Frank  0.027380  boy
# 6  1880   Joseph  0.022229  boy
# 7  1880   Thomas  0.021401  boy
# 8  1880    Henry  0.020641  boy

# %%
#I want to find out the most popular baby name from 1880 - 2009
#Now we do some data transformation and clean the dataframe for your answer
#I will create a new
Wordclouddata2 = Wordclouddata ['name']

# %%
# ?Wordcloud


#import world cloud libraries
#STOPWORDS is a function that automatically removes words from your results
#Most commonly imported as a seperate file and joined with the data frame
from wordcloud import WordCloud, STOPWORDS
wordcloud=WordCloud(
                        background_color= "white",
                        stopwords=STOPWORDS,
                        max_words=150,
                        max_font_size=70,
                        random_state=0
                       ).generate(str(Wordclouddata2))

# Display the generated image:
plt.imshow(wordcloud, interpolation= 'bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
# Out:
# Object `Wordcloud` not found.

# %%
# ?Wordcloud


#import world cloud libraries
#STOPWORDS is a function that automatically removes words from your results
#Most commonly imported as a seperate file and joined with the data frame
from wordcloud import WordCloud, STOPWORDS
wordcloud=WordCloud(
                        background_color= "white",
                        stopwords=['object', 'length', 'dtype', 'Name'],
                        #stopwords=STOPWORDS,
                        max_words=4,
                        max_font_size=70,
                        random_state=0
                       ).generate(str(Wordclouddata3))

# Display the generated image:
plt.imshow(wordcloud, interpolation= 'bilinear')
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
# Out:
# Object `Wordcloud` not found.

# %%
#Lets take it one step further and say I want to replace junj
Wordclouddata3=Wordclouddata2.replace('John', 'Matt')
